# %% [markdown]
# ### 기능 1 - 데이터 불러오기(load_data)

# %%
import pandas as pd
import os
import numpy as np

# 파일 경로
BASE_DIR = os.getcwd()
FILE_PATH = os.path.join(os.path.dirname(BASE_DIR),
                         "data","student_habits_clean.csv")

# 1. 데이터 불러오기
def load_data(file_path):
    if not os.path.exists(file_path):
        print(f"파일을 찾을 수 없습니다: {file_path}")
        return None

    df = pd.read_csv(file_path, encoding="utf-8-sig")

    print("\n[1. 데이터 불러오기]")
    print("데이터 로드 완료:", df.shape[0], "행 X", df.shape[1], "열")
    return df

# %% [markdown]
# ### 기능 2 - 데이터 구조 확인(explore_structure)

# %%
def explore_structure(df):
    print("\n[2. 데이터 구조 확인]")

    print("\n1. 데이터 행, 열:")
    print(df.shape)

    print("\n2. 컬럼, 자료형:")
    print(df.dtypes)

    print("\n3. 상위 5개 데이터:")
    print(df.head())

    print("\n4. 데이터 정보:")
    df.info()

# %% [markdown]
# ### 기능 3 - 기술통계 출력(show_statistics)

# %%
# 수치형 컬럼 전체의 기술통계를 출력

def show_statistics(df):
    print("\n[3. 기술통계 출력]")

    # 수치형 컬럼의 기술통계 출력
    print(df.describe().round(3))

    print("\n수치형 컬럼별 평균:")

    number_columns = df.select_dtypes(include=["number"]).columns

    for col in number_columns:      # 수치형 컬럼 각각의 평균을 반복문으로 순회하며 한 줄씩 출력
        print(f"{col}: {round(df[col].mean(), 4)}")
    
    # count : 데이터 수
    # mean : 평균
    # std : 표준편차
    # min : 최소값
    # 25% : 1사분위수
    # 50% : 2사분위수(중앙값)  
    # 75% : 3사분위수
    # max : 최대값

# %% [markdown]
# ### 기능 4 - 결측치 현황 파악(check_missing)

# %%
def check_missing(df):
    print("\n[4. 결측치 현황 파악]")

    df_missing = pd.DataFrame({
        "결측치 수": df.isnull().sum(),
        "결측치 비율(%)": df.isnull().mean() * 100
    })

    def missing_ratio(ratio):
        if ratio < 5:
            return "낮음"
        elif ratio < 20:
            return "주의"
        else:
            return "높음"

    df_missing["심각도"] = df_missing["결측치 비율(%)"].apply(missing_ratio)
    df_missing["결측치 비율(%)"] = df_missing["결측치 비율(%)"].round(2)
    print(df_missing)

    return df_missing

# %% [markdown]
# ### 기능 5 - NumPy로 직접 통계량 계산 (numpy_stats)

# %%
def numpy_stats(df):
    print("\n[5. NumPy 통계량 계산]")

    # 결측치 제거 후 NumPy 배열로 변환(study_hours 컬럼)
    df_null = df.dropna()
    study_hours = df_null.values[:, 5]

    print("\n1. NumPy 기술통계")
    print("mean:", round(np.mean(study_hours), 3)) # 평균
    
    print("std:", round(np.std(study_hours), 3)) # 표준편차

    print("median:", round(np.median(study_hours), 3)) # 중앙값
    print("min:", round(np.min(study_hours), 3)) # 최소값
    print("max:", round(np.max(study_hours), 3)) # 최댓값

    print("\n2. pandas 기술통계")
    pandas_stats = df_null["study_hours"].dropna().agg(["mean", "std", "median", "min", "max"]).round(3)

    print(pandas_stats)

    print("\n3. 6시간 이상 공부하는 학생 수")

    student_count = df_null[df_null["study_hours"] >= 6]

    print(student_count["student_id"].count())

# %% [markdown]
# ### 기능 6 - main() 함수로 전체 연결

# %%
# 6. 전체 함수 연결(main)
def main():
    df = load_data(FILE_PATH)

    if df is not None:
        explore_structure(df)
        show_statistics(df)
        check_missing(df)
        numpy_stats(df)

if __name__ == "__main__":
    main()
# Out:
# [1. 데이터 불러오기]
# 데이터 로드 완료: 200 행 X 13 열
#
# [2. 데이터 구조 확인]
#
# 1. 데이터 행, 열:
# (200, 13)
#
# 2. 컬럼, 자료형:
# student_id              str
# gender                  str
# grade_year            int64
# major                   str
# sleep_hours         float64
# study_hours         float64
# phone_hours         float64
# exercise_hours      float64
# score               float64
# gender_code           int64
# productive_hours    float64
# sleep_sufficient      int64
# phone_overuse         int64
# dtype: object
#
# 3. 상위 5개 데이터:
#   student_id gender  grade_year major  sleep_hours  study_hours  phone_hours  \
# 0       S001      여           1  인문사회          7.2          5.4          1.1
# 1       S002      여           2  인문사회          7.5          4.3          2.6
# 2       S003      여           4   이공계          8.1          5.7          3.5
# 3       S004      남           2   이공계          8.1          7.2          3.6
# 4       S005      남           2   이공계          5.1          4.1          2.8
#
#    exercise_hours  score  gender_code  productive_hours  sleep_sufficient  \
# 0             1.8   92.2            1               7.2                 1
# 1             0.5   75.0            1               4.8                 1
# 2             1.9   85.7            1               7.6                 1
# 3             2.3   90.4            0               9.5                 1
# 4             1.5   71.5            0               5.6                 0
#
#    phone_overuse
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
#
# 4. 데이터 정보:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        200 non-null    str
#  1   gender            200 non-null    str
#  2   grade_year        200 non-null    int64
#  3   major             200 non-null    str
#  4   sleep_hours       200 non-null    float64
#  5   study_hours       200 non-null    float64
#  6   phone_hours       200 non-null    float64
#  7   exercise_hours    200 non-null    float64
#  8   score             200 non-null    float64
#  9   gender_code       200 non-null    int64
#  10  productive_hours  200 non-null    float64
#  11  sleep_sufficient  200 non-null    int64
#  12  phone_overuse     200 non-null    int64
# dtypes: float64(6), int64(4), str(3)
# memory usage: 20.4 KB
#
# [3. 기술통계 출력]
#        grade_year  sleep_hours  study_hours  phone_hours  exercise_hours  \
# count     200.000      200.000      200.000      200.000         200.000
# mean        2.360        6.923        4.488        3.389           1.233
# std         1.052        1.117        1.692        1.450           0.759
# min         1.000        4.300        0.500        0.500           0.000
# 25%         1.000        6.100        3.300        2.400           0.675
# 50%         2.000        6.900        4.550        3.400           1.200
# 75%         3.000        7.600        5.425        4.300           1.700
# max         4.000        9.850        8.613        7.150           3.238
#
#          score  gender_code  productive_hours  sleep_sufficient  phone_overuse
# count  200.000      200.000           200.000            200.00        200.000
# mean    77.318        0.480             5.722              0.46          0.335
# std      9.819        0.501             1.892              0.50          0.473
# min     49.200        0.000             0.600              0.00          0.000
# 25%     70.875        0.000             4.275              0.00          0.000
# 50%     77.400        0.000             5.650              0.00          0.000
# 75%     83.600        1.000             7.100              1.00          1.000
# max    100.000        1.000            10.500              1.00          1.000
#
# 수치형 컬럼별 평균:
# grade_year: 2.36
# sleep_hours: 6.9228
# study_hours: 4.4883
# phone_hours: 3.389
# exercise_hours: 1.2334
# score: 77.3185
# gender_code: 0.48
# productive_hours: 5.7216
# sleep_sufficient: 0.46
# phone_overuse: 0.335
#
# [4. 결측치 현황 파악]
#                   결측치 수  결측치 비율(%) 심각도
# student_id            0        0.0  낮음
# gender                0        0.0  낮음
# grade_year            0        0.0  낮음
# major                 0        0.0  낮음
# sleep_hours           0        0.0  낮음
# study_hours           0        0.0  낮음
# phone_hours           0        0.0  낮음
# exercise_hours        0        0.0  낮음
# score                 0        0.0  낮음
# gender_code           0        0.0  낮음
# productive_hours      0        0.0  낮음
# sleep_sufficient      0        0.0  낮음
# phone_overuse         0        0.0  낮음
#
# [5. NumPy 통계량 계산]
#
# 1. NumPy 기술통계
# mean: 4.488
# std: 1.688
# median: 4.55
# min: 0.5
# max: 8.613
#
# 2. pandas 기술통계
# mean      4.488
# std       1.692
# median    4.550
# min       0.500
# max       8.613
# Name: study_hours, dtype: float64
#
# 3. 6시간 이상 공부하는 학생 수
# 37
